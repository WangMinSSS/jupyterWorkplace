# %% [markdown]
# ### 说明：
# 验证几何代数匹配滤波器在线性调频雷达信号前提下的抗间歇采样转发干扰的性能

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg
from scipy import stats
from scipy import signal
import sys

# %% [markdown]
# #### 1.线性调频信号
# $y=e^{j{\pi}\frac{B}{\tau}t^2}$
#
# *B为扫频宽度，$\tau$为脉冲宽度*

# %%
#### 参数设置

pluseWidth = 100e-6    # 脉冲宽度(持续时间s)
prf = 1e3            # 重复频率Hz
B = 5e6              # 扫频宽度

fs = 1e9            # 采样频率Hz

lightSpeed = 3e8     # 光速

#### 信号产生

t = np.linspace(-pluseWidth/2, pluseWidth/2, int(fs*pluseWidth))
T = np.linspace(0, 1/prf, int(fs/prf))

sig = np.exp(1j*np.pi*B/pluseWidth*(t**2))
sig_I = np.real(sig)
sig_Q = np.imag(sig)

fftI = np.abs(np.fft.fft(sig_I))

#### 作图

plt.figure(figsize=(20, 8))

plt.subplot('211')
plt.plot(t, sig_I)
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of signal_I')

plt.subplot('212')
plt.plot(np.linspace(0, fs, int(fs*pluseWidth)), fftI)
plt.xlabel('Hz')
plt.ylabel('amplitude')
# plt.yscale('log')
# plt.xlim(xmin=0,xmax=1e8)
plt.title('frequence waveform of signal_I')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-e906fbf7699f> in <module>
#      12
#      13 t = np.linspace(-pluseWidth/2, pluseWidth/2, int(fs*pluseWidth))
# ---> 14 T = np.linspace(0, 1/prf, int(fs/prf))
#      15
#      16 sig = np.exp(1j*np.pi*B/pluseWidth*(t**2))
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype)
#     113         dtype = dt
#     114
# --> 115     y = _nx.arange(0, num, dtype=dt)
#     116
#     117     delta = stop - start
#
# MemoryError:

# %% [markdown]
# #### 2.间歇采样转发干扰
# * 间歇采样信号是一个矩形脉冲串p(t):
#
# $p(t)=rect(\frac{t}{\tau})*\sum_{-\infty}^{+\infty}\delta(t-nT_s)$
#
# *$\tau$为脉宽，$T_s$为采样周期，$T_s$远小于雷达脉冲宽度，$\frac{1}{T_s}$大于雷达脉冲带宽时产生干扰效果*
#
# * 设雷达发射信号为x(t),其时宽为T,带宽为B,频谱为X(f).⼲扰机收到雷达信号后,对其进⾏间歇采样处理,即以p(t)与其做相乘运算,得采样信号为：
#
# $x_s(t)=p(t)x(t)$

# %%
#### 参数设置
Ts = pluseWidth/25
pw = Ts/2

#### 干扰产生

jam_p = np.array([])
while len(jam_p)<len(sig_I):
    jam_p = np.concatenate((jam_p,np.ones(int(pw*fs))))
    jam_p = np.concatenate((jam_p,np.zeros(int((Ts-pw)*fs))))

jam_p = jam_p[0:len(sig_I)]
jam = np.multiply(jam_p,sig_I)
jam_Q = np.multiply(jam_p,sig_Q)

fft_jam_p = np.abs(np.fft.fft(jam_p))
fft_jam = np.abs(np.fft.fft(jam))

#### 作图

plt.figure(figsize=(20, 16))

plt.subplot('411')
plt.plot(t, jam_p)
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of rect')

plt.subplot('412')
plt.plot(np.linspace(0, fs, int(fs*pluseWidth)), fft_jam_p)
plt.xlabel('Hz')
plt.ylabel('amplitude')
# plt.yscale('log')
# plt.xlim(xmin=0,xmax=1e8)
plt.title('frequence waveform of rect')

plt.subplot('413')
plt.plot(t, jam)
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of jamming')

plt.subplot('414')
plt.plot(np.linspace(0, fs, int(fs*pluseWidth)), fft_jam)
plt.xlabel('Hz')
plt.ylabel('amplitude')
# plt.yscale('log')
# plt.xlim(xmin=0,xmax=1e8)
plt.title('frequence waveform of jamming')

plt.show()

# %% [markdown]
# #### 3.匹配滤波
# $y(t)=IFFT[X(f)X*(f)]$

# %%
#### 原信号匹配滤波
sig_match1 = np.fft.ifft(np.fft.fft(sig_I+1j*sig_Q)*np.fft.fft(sig_I-1j*sig_Q))

#### 干扰信号匹配滤波
sig_match2 = np.fft.ifft(np.fft.fft(jam+1j*jam_Q)*np.fft.fft(sig_I-1j*sig_Q))

#### 画图
plt.figure(figsize=(20,8))

plt.subplot('211')
plt.plot(np.real(sig_match1))
plt.title('match filter of radar signal')

plt.subplot('212')
plt.plot(np.real(sig_match2))
plt.title('match filter of jamming')
plt.show()

# %% [markdown]
# #### 4.雷达信号与干扰信号叠加

# %%
#### 参数设置
R = 50000 # 目标距离m
R_jam = 51000 # 假目标距离m

#### 回波产生
sig_IF = np.concatenate((np.zeros(int(2*R/lightSpeed*fs)), sig_I))
sig_IF = np.concatenate((sig_IF, np.zeros(len(T)-len(sig_IF))))

fftIF = np.abs(np.fft.fft(sig_IF))

sig_IFQ = np.concatenate((np.zeros(int(2*R/lightSpeed*fs)), sig_Q))
sig_IFQ = np.concatenate((sig_IFQ, np.zeros(len(T)-len(sig_IFQ))))


sig_IF_jam = np.concatenate((np.zeros(int(2*R_jam/lightSpeed*fs)), jam))
sig_IF_jam = np.concatenate((sig_IF_jam, np.zeros(len(T)-len(sig_IF_jam))))

sig_IFQ_jam = np.concatenate((np.zeros(int(2*R_jam/lightSpeed*fs)), jam_Q))
sig_IFQ_jam = np.concatenate((sig_IFQ_jam, np.zeros(len(T)-len(sig_IFQ_jam))))

##### 噪声产生
SNR = 1e1 #信噪比
G_var = 1/SNR  # 高斯白噪声方差

G_noise_I = stats.norm.rvs(loc=0, scale=G_var, size=int(fs/prf))
G_noise_Q = stats.norm.rvs(loc=0, scale=G_var, size=int(fs/prf))

#### 回波叠加
echo_I = sig_IF+sig_IF_jam+G_noise_I
echo_Q = sig_IFQ+sig_IFQ_jam+G_noise_Q

fftEcho = np.abs(np.fft.fft(echo_I))


sig_I1 = np.concatenate((sig_I, np.zeros(len(T)-len(sig_I))))
sig_Q1 = np.concatenate((sig_Q, np.zeros(len(T)-len(sig_Q))))
sig_match_IF = np.fft.ifft(np.fft.fft(sig_IF+1j*sig_IFQ)*np.fft.fft(sig_I1-1j*sig_Q1))
sig_match_echo = np.fft.ifft(np.fft.fft(echo_I+1j*echo_Q)*np.fft.fft(sig_I1-1j*sig_Q1))

#### 作图
plt.figure(figsize=(20, 24))

plt.subplot('411')
plt.plot(np.real(sig_match_IF))
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of echo')

plt.subplot('412')
plt.plot(T, echo_I)
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of echo')

plt.subplot('413')
plt.plot(np.linspace(0, fs, int(fs/prf)), fftEcho)
plt.xlabel('Hz')
plt.ylabel('amplitude')
# plt.yscale('log')
# plt.xlim(xmin=0,xmax=1e8)
plt.title('frequence waveform of echo')

plt.subplot('414')
plt.plot(np.real(sig_match_echo))
plt.xlabel('t')
plt.ylabel('amplitude')
plt.title('time waveform of echo')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-b989785087f9> in <module>
#       7 sig_IF = np.concatenate((sig_IF, np.zeros(len(T)-len(sig_IF))))
#       8
# ----> 9 fftIF = np.abs(np.fft.fft(sig_IF))
#      10
#      11 sig_IFQ = np.concatenate((np.zeros(int(2*R/lightSpeed*fs)), sig_Q))
#
# ~/anaconda3/lib/python3.7/site-packages/mkl_fft/_numpy_fft.py in fft(a, n, axis, norm)
#     156
#     157     """
# --> 158     output = mkl_fft.fft(a, n, axis)
#     159     if _unitary(norm):
#     160         output *= 1 / sqrt(output.shape[axis])
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti.fft()
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti._fft1d_impl()
#
# mkl_fft/_pydfti.pyx in mkl_fft._pydfti.__allocate_result()
#
# MemoryError:

# %% [markdown]
# #### 结论分析
